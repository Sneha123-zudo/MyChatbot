# %%
# !pip install langchain langchain_ollama langchain_community langgraph faiss-cpu pypdf
# Out:
# ...
#   Using cached langchain_ollama-1.0.1-py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached ollama-0.6.1-py3-none-any.whl.metadata (4.3 kB)
# ...
#   Using cached python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# ...
# Using cached langchain_ollama-1.0.1-py3-none-any.whl (29 kB)
# ...
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 2.5/2.5 MB 12.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/18.9 MB ? eta -:--:--
#    --------- ------------------------------ 4.5/18.9 MB 26.9 MB/s eta 0:00:01
#    --------------------- ------------------ 10.0/18.9 MB 25.9 MB/s eta 0:00:01
#    -------------------------------- ------- 15.5/18.9 MB 25.0 MB/s eta 0:00:01
#    ---------------------------------------  18.9/18.9 MB 25.4 MB/s eta 0:00:01
#    ---------------------------------------- 18.9/18.9 MB 21.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
# ...

# %%
from langchain
